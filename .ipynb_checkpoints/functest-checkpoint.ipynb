# %%
from IPython.display import Audio

# %%
def beep():
    return Audio(filename="MainTitle.mp3", autoplay=True)
#     return Audio(np.sin(np.pi*100*np.arange(1000*5)/1000), rate=5000, autoplay=True)

# %%
beep()
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from tqdm import tnrange,tqdm_notebook
from time import sleep
for i in tnrange(5, desc='1st loop'):
    for j in tnrange(100, desc='2nd loop'):
        sleep(0.1)

# %%
for i in tqdm_notebook(range(100), desc='Loop'):\
    sleep(0.1)

# %%
# Out:
# UsageError: Line magic function `%%notify` not found.

# %%
# %load_ext jupyternotify
# Out:
# The jupyternotify extension is already loaded. To reload it, use:
#   %reload_ext jupyternotify

# %%
# %%notify -m "Hello"
# sleep(5)
